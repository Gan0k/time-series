# %%
# %matplotlib inline

import matplotlib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data2006 = pd.read_csv('2006.txt',';',na_values='?')
data2006.dtypes
# Out:
# Date                      object
# Time                      object
# Global_active_power      float64
# Global_reactive_power    float64
# Voltage                  float64
# Global_intensity         float64
# Sub_metering_1           float64
# Sub_metering_2           float64
# Sub_metering_3           float64
# dtype: object

# %%
data2006.Sub_metering_1.plot()

# %%
data2006.Sub_metering_2.plot()

# %%
data2006.Sub_metering_3.plot()

# %%
data2006.Global_active_power.plot()

# %%
data2006.Voltage[1:7*60*24].plot()

# %%
data2006.Global_intensity[1:60*10].plot()

# %%
other = data2006.Global_active_power*1000/60 - data2006.Sub_metering_1 - data2006.Sub_metering_2 - data2006.Sub_metering_3
other[1:10*60].plot()

# %%
data2006[100:201]
# Out:
#            Date      Time  Global_active_power  Global_reactive_power  \
# 100  16/12/2006  19:04:00                3.366                  0.000
# 101  16/12/2006  19:05:00                3.404                  0.082
# 102  16/12/2006  19:06:00                3.382                  0.074
# 103  16/12/2006  19:07:00                3.616                  0.106
# 104  16/12/2006  19:08:00                3.476                  0.092
# 105  16/12/2006  19:09:00                3.394                  0.064
# 106  16/12/2006  19:10:00                3.400                  0.000
# 107  16/12/2006  19:11:00                3.414                  0.000
# 108  16/12/2006  19:12:00                3.432                  0.000
# 109  16/12/2006  19:13:00                3.418                  0.000
# 110  16/12/2006  19:14:00                3.392                  0.000
# 111  16/12/2006  19:15:00                3.394                  0.000
# ...
